# %% [markdown]
# ## Loading the Data

# %%
import pandas as pd

# %%
df=pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.max_columns=None

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# ## Analyzing Class Distribution

# %%
fraud = df[df['Class'] == 1]
valid = df[df['Class'] == 0]
print("Outlier Fraction:")
outlierFraction = len(fraud)/float(len(valid))
print(outlierFraction)
print('Fraud Cases: {}'.format(len(df[df['Class'] == 1])))
print('Valid Transactions: {}'.format(len(df[df['Class'] == 0])))
# Out:
# Outlier Fraction:
# 0.0017304750013189597
# Fraud Cases: 492
# Valid Transactions: 284315

# %%
print("Amount details of the fraudulent transaction")
fraud.Amount.describe()
# Out:
# Amount details of the fraudulent transaction
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
print("details of valid transaction")
valid.Amount.describe()
# Out:
# details of valid transaction
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
df['Amount']=sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df=df.drop(['Time'],axis=1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
df.duplicated().any()
# Out:
# True

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (275663, 30)

# %%
df['Class'].value_counts() ## Imbalanced dataset
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## Plotting Correlation Matrix

# %%
corrmat = df.corr()
fig = plt.figure(figsize = (12, 9))
sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# We can visualize the correlation between features using a heatmap using correlation matrix. This will give us an understanding of how the different features are correlated and which ones may be more relevant for prediction.
# Most features do not correlate strongly with others but some features like V2 and V5 have a negative correlation with the Amount feature. This provides valuable insights into how the features are related to the transaction amounts.

# %% [markdown]
# # Preparing Data

# %%
x=df.drop('Class',axis=1)
y=df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Model Evaluation

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score

# %%
classifier={
    "LogisticRregression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name,clf in classifier.items():
    print(f"\n========{name}=========")
    clf.fit(x_train,y_train)
    y_pred=clf.predict(x_test)
    print(f"\nAccuracy=:{accuracy_score(y_test,y_pred)}")
    print(f"\nPrecision=:{precision_score(y_test,y_pred)}")
    print(f"\nRecall=:{recall_score(y_test,y_pred)}")
    print(f"\nF1 Score=:{f1_score(y_test,y_pred)}")
# Out:
# ========LogisticRregression=========
#
# Accuracy=:0.9992563437505668
#
# Precision=:0.890625
#
# Recall=:0.6263736263736264
#
# F1 Score=:0.7354838709677419
#
# ========Decision Tree Classifier=========
#
# Accuracy=:0.9990205503056245
#
# Precision=:0.6868686868686869
#
# Recall=:0.7472527472527473
#
# F1 Score=:0.7157894736842105

# %% [markdown]
# # Under Sampling
# ### It causes loss of data

# %%
normal=df[df['Class']==0]
fraud=df[df['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
data=pd.concat([normal_sample,fraud],ignore_index=True)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.143521  0.209867  0.926654  1.885986 -0.498746 -0.101639 -0.193784
# 1 -1.311584  1.378727  1.696450  0.202115  0.261998  0.595865  0.064100
# 2  1.930024 -0.342298 -0.763038  0.202205 -0.458362 -0.995338 -0.011598
# 3 -2.501014  2.056529  0.111806  0.917107 -1.291148  0.237563 -0.948522
# 4 -1.099054  0.469159  1.964596  1.077680  0.335675  2.321662 -0.267541
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.049292 -0.446398  0.541637  1.085872  1.299194  0.513013 -0.183231
# 1  0.599279 -0.699333 -0.372832 -2.157087  0.132396  1.630703 -0.589240
# 2 -0.217400  1.266199 -0.384868 -0.817354  0.680754 -0.053586  0.174485
# 3  1.473037  0.114912 -0.208801 -2.000042  0.749932  1.080367  0.297359
# 4  0.748641  0.740536 -0.049074 -1.014887  0.639430 -0.065370 -0.896797
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
x=data.drop('Class',axis=1)
y=data['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,confusion_matrix

# %%
classifier={
    "LogisticRregression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name,clf in classifier.items():
    print(f"\n========{name}=========")
    clf.fit(x_train,y_train)
    y_pred=clf.predict(x_test)
    print(f"\nAccuracy=:{accuracy_score(y_test,y_pred)}")
    print(f"\nPrecision=:{precision_score(y_test,y_pred)}")
    print(f"\nRecall=:{recall_score(y_test,y_pred)}")
    print(f"\nF1 Score=:{f1_score(y_test,y_pred)}")
# Out:
# ========LogisticRregression=========
#
# Accuracy=:0.9157894736842105
#
# Precision=:0.9215686274509803
#
# Recall=:0.9215686274509803
#
# F1 Score=:0.9215686274509803
#
# ========Decision Tree Classifier=========
#
# Accuracy=:0.9315789473684211
#
# Precision=:0.9320388349514563
#
# Recall=:0.9411764705882353
#
# F1 Score=:0.9365853658536586

# %% [markdown]
# # Over Sampling

# %%
x=df.drop('Class',axis=1)
y=df['Class']

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
x_res,y_res=SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x_res,y_res,test_size=0.2,random_state=42)

# %%
classifier={
    "LogisticRregression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name,clf in classifier.items():
    print(f"\n========{name}=========")
    clf.fit(x_train,y_train)
    y_pred=clf.predict(x_test)
    print(f"\nAccuracy=:{accuracy_score(y_test,y_pred)}")
    print(f"\nPrecision=:{precision_score(y_test,y_pred)}")
    print(f"\nRecall=:{recall_score(y_test,y_pred)}")
    print(f"\nF1 Score=:{f1_score(y_test,y_pred)}")
# Out:
# ========LogisticRregression=========
#
# Accuracy=:0.944620080671536
#
# Precision=:0.9729792460493994
#
# Recall=:0.9145682962747487
#
# F1 Score=:0.9428699955015745
#
# ========Decision Tree Classifier=========
#
# Accuracy=:0.9981830735128456
#
# Precision=:0.9973500317633179
#
# Recall=:0.9990182353689798
#
# F1 Score=:0.998183436574688

# %% [markdown]
# # Confusion Matrix

# %% [markdown]
# Confusion Matrix Components:
# It visually represents the predicted versus actual classifications, showing the counts of True Positives (TP), True Negatives (TN), False Positives (FP), and False Negatives (FN).

# %% [markdown]
# Purpose:
# This matrix helps assess how well a classification model distinguishes between different classes (e.g., "Normal" and "Fraud" in this case).

# %%
import seaborn as sns
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",xticklabels=['Normal', 'Fraud'], yticklabels=['Normal', 'Fraud'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.show()

# %% [markdown]
# Interpretation:

# %% [markdown]
# 54930 (True Negatives): The model correctly predicted "Normal" when the true class was "Normal."

# %% [markdown]
# 143 (False Positives): The model incorrectly predicted "Fraud" when the true class was "Normal."

# %% [markdown]
# 67 (False Negatives): The model incorrectly predicted "Normal" when the true class was "Fraud."

# %% [markdown]
# 54936 (True Positives): The model correctly predicted "Fraud" when the true class was "Fraud."

# %%
pred=clf.predict(x_test)

# %%
pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
print(pred)
# Out:
# [1 1 1 ... 0 1 1]

# %%
# Create and train the decision tree
dtree = DecisionTreeClassifier()
dtree.fit(x, y)  # Ensure 'x' and 'y' are your features and target
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
plt.figure(figsize=(100,50))
tree.plot_tree(dtree,feature_names=x.columns,class_names=['Class-1', 'Class-0'],rounded=True, # Rounded node edges
          filled=True, # Adds color according to class
          proportion=True
        )
plt.show()

# %%
# 1. Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# 2. Load data
df = pd.read_csv("creditcard.csv")  # Replace with actual filename

# 3. Separate features and target
X = df.drop("Class", axis=1)
y = df["Class"]

# 4. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 5. Scaling (define scaler here!)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 6. Train model
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)

# 7. Now make prediction
new_data = [[
    100000,  # Example Time value (you can replace with realistic value)
    0.461877, -0.620374, 0.461907, -1.845106, -0.413504, -0.313525, -0.539897, -0.093528,
    -2.160194, 1.173114, -1.017285, -0.904699, 1.033564, -0.597283, 0.102413, -1.030859,
    0.805055, 0.008129, 0.763237, -0.155553, -0.137453, 0.059526, -0.037204, 0.605697,
    0.002425, -0.000834, -0.007424, -0.069270, -0.333239  # Amount
]]

# Ensure columns match X_train
new_data_df = pd.DataFrame(new_data, columns=X.columns)

# Now transform and predict
new_data_scaled = scaler.transform(new_data_df)
prediction = model.predict(new_data_scaled)

print("Prediction (0 = Not Fraud, 1 = Fraud):", prediction[0])
# Out:
# Prediction (0 = Not Fraud, 1 = Fraud): 0
